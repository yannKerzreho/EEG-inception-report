# %%
! python exp1.py
# Out:
# === Expérience Globale (Train Global -> Test par Sujet) ===
# Chargement et fusion des données de tous les sujets...
# Loading Data: 100%|███████████████████████████████| 9/9 [00:08<00:00,  1.08it/s]
# Dataset Global Train: (2328, 22, 1875)
# Dataset Global Test : (2592, 22, 1875)
#
# Calibration des bruits...
# Noise SD : tensor([1.6024, 1.6785, 1.6117, 1.6048, 1.6037, 1.6873, 1.8728, 1.6685, 1.6331,
#         1.6326, 1.5958, 1.6733, 1.8884, 1.6403, 1.5905, 1.5954, 1.5682, 1.6176,
#         1.5975, 1.5745, 1.5539, 1.5975])
#
# === Condition : GausAug ===
# Train GausAug: 100%|█| 100/100 [3:08:36<00:00, 113.16s/epoch, Loss=0.0095, ValAc
#
# --- Évaluation détaillée par sujet ---
#  >> Moyenne Globale Finale pour GausAug : 40.32%
#
# === Condition : FreqAug ===
# Train FreqAug: 100%|█| 100/100 [3:08:47<00:00, 113.27s/epoch, Loss=0.0290, ValAc
#
# --- Évaluation détaillée par sujet ---
#  >> Moyenne Globale Finale pour FreqAug : 54.32%
#
# === Condition : Baseline ===
# ...

# %%
! python exp1.py
# Out:
# === Expérience Globale (Train Global -> Test par Sujet) ===
# Chargement et fusion des données de tous les sujets...
# Loading Data: 100%|███████████████████████████████| 9/9 [00:08<00:00,  1.10it/s]
# Dataset Global Train: (2328, 22, 1875)
# Dataset Global Test : (2592, 22, 1875)
#
# Calibration des bruits...
# Noise SD : tensor([1.6024, 1.6785, 1.6117, 1.6048, 1.6037, 1.6873, 1.8728, 1.6685, 1.6331,
#         1.6326, 1.5958, 1.6733, 1.8884, 1.6403, 1.5905, 1.5954, 1.5682, 1.6176,
#         1.5975, 1.5745, 1.5539, 1.5975])
# Train GausAug:   0%|                                     | 0/60 [00:00<?, ?ep/s]
