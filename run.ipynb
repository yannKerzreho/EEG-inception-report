# %%
! python exp1.py
# Out:
# === Expérience Globale (Train Global -> Test par Sujet) ===
# Chargement et fusion des données de tous les sujets...
# Loading Data: 100%|███████████████████████████████| 9/9 [00:08<00:00,  1.01it/s]
# Dataset Global Train: (2328, 22, 1875)
# Dataset Global Test : (2592, 22, 1875)
#
# Calibration des bruits...
# Noise SD : tensor([1.6024, 1.6785, 1.6117, 1.6048, 1.6037, 1.6873, 1.8728, 1.6685, 1.6331,
#         1.6326, 1.5958, 1.6733, 1.8884, 1.6403, 1.5905, 1.5954, 1.5682, 1.6176,
#         1.5975, 1.5745, 1.5539, 1.5975])
# Train GausAug: 100%|█| 200/200 [3:13:04<00:00, 57.92s/ep, Loss=0.0013, Acc=56.60
#  >> Moyenne Globale Finale pour GausAug : 54.32%
# Train Baseline: 100%|█| 200/200 [3:13:05<00:00, 57.93s/ep, Loss=0.0802, Acc=46.4
#  >> Moyenne Globale Finale pour Baseline : 44.56%
#
# === TABLEAU RÉCAPITULATIF (Accuracy %) ===
# Method      Baseline  FreqAug  GausAug   Mean
# Subject
# 1              55.56    69.10    65.28  63.31
# ...

# %%
! python exp2.py
# Out:
# === Expérience Globale (Train Global -> Test par Sujet) ===
# Chargement et fusion des données de tous les sujets...
# Loading Data: 100%|███████████████████████████████| 9/9 [00:08<00:00,  1.05it/s]
# Dataset Global Train: (2328, 22, 1875)
# Dataset Global Test : (2592, 22, 1875)
# T|n_filters=4: 100%|█| 200/200 [20:11<00:00,  6.06s/ep, Loss=0.0011, Acc=40.40%]
#  >> Moyenne Globale Finale pour 4 : 40.59%
# T|n_filters=8: 100%|█| 200/200 [33:50<00:00, 10.15s/ep, Loss=0.0003, Acc=45.00%]
#  >> Moyenne Globale Finale pour 8 : 47.80%
# T|n_filters=16: 100%|█| 200/200 [47:01<00:00, 14.11s/ep, Loss=0.0005, Acc=58.20%
#  >> Moyenne Globale Finale pour 16 : 57.25%
# T|n_filters=32: 100%|█| 200/200 [1:45:34<00:00, 31.67s/ep, Loss=0.0008, Acc=52.2
#  >> Moyenne Globale Finale pour 32 : 53.43%
#
# === TABLEAU RÉCAPITULATIF (Accuracy %) ===
# n_filters      16     32      4      8   Mean
# Subject
# 1           66.32  65.97  45.49  55.56  58.33
# 2           34.03  34.03  29.86  34.72  33.16
# ...

# %%
! python exp3.py
# Out:
# === Expérience Augmentation (n=16) Multi-Seed ===
# Chargement et fusion des données de tous les sujets...
# Loading Data: 100%|███████████████████████████████| 9/9 [00:08<00:00,  1.06it/s]
#
# Calibration des bruits...
# Noise SD ref (3 premiers) : tensor([1.6024, 1.6785, 1.6117])
#
# >>> Méthode : Baseline
#    Run Seed 1 -> Avg Acc: 47.26%
#    Run Seed 2 -> Avg Acc: 53.16%
#    Run Seed 3 -> Avg Acc: 53.78%
#
# >>> Méthode : FreqAug
#    Run Seed 1 -> Avg Acc: 55.32%
#    Run Seed 2 -> Avg Acc: 56.33%
#    Run Seed 3 -> Avg Acc: 51.62%
#
# >>> Méthode : GausAug
#    Run Seed 1 -> Avg Acc: 54.51%
#    Run Seed 2 -> Avg Acc: 56.21%
#    Run Seed 3 -> Avg Acc: 53.32%
#
# Génération des graphiques...
#
# === PERFORMANCES GLOBALES (Moyenne des 5 Seeds) ===
#      Method   mean   std    min    max
# 0  Baseline  51.40  3.60  47.26  53.78
# 1   FreqAug  54.42  2.48  51.62  56.33
# 2   GausAug  54.68  1.45  53.32  56.21

# %%
! python exp2.py
# Out:
# === Expérience Multi-Seed [1, 2, 3] ===
# Chargement et fusion des données de tous les sujets...
# Loading Data: 100%|███████████████████████████████| 9/9 [00:07<00:00,  1.13it/s]
# Dataset Global Train: (2328, 22, 1875)
# Dataset Global Test : (2592, 22, 1875)
#
# >>> DÉBUT SEED 1 <<<
#
# >>> DÉBUT SEED 2 <<<
#
# >>> DÉBUT SEED 3 <<<
# Génération des graphiques...
# Calcul des statistiques finales...
#
# === TABLEAU RÉCAPITULATIF : Mean ± SD (Min - Max) ===
# n_filters                           16  ...                           8
# Subject                                 ...
# 1            59.14 ±8.15 (52.08-68.06)  ...   46.88 ±7.73 (38.54-53.82)
# 2            34.84 ±3.87 (31.94-39.24)  ...   32.52 ±6.33 (25.69-38.19)
# 3            65.28 ±5.72 (58.68-68.75)  ...  50.81 ±13.16 (42.36-65.97)
# 4            47.34 ±4.40 (43.40-52.08)  ...   40.97 ±5.39 (35.42-46.18)
# 5            27.08 ±3.61 (25.00-31.25)  ...   29.51 ±3.35 (27.08-33.33)
# ...
