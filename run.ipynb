# %%
! python exp1.py
# Out:
# === Expérience Globale (Train Global -> Test par Sujet) ===
# Chargement et fusion des données de tous les sujets...
# Loading Data: 100%|███████████████████████████████| 9/9 [00:08<00:00,  1.08it/s]
# Dataset Global Train: (2328, 22, 1875)
# Dataset Global Test : (2592, 22, 1875)
#
# Calibration des bruits...
# Scale global : tensor([0.1157, 0.1481, 0.1345, 0.1275, 0.1305, 0.1401, 0.2058, 0.1585, 0.1455,
#         0.1378, 0.1383, 0.1470, 0.1792, 0.1566, 0.1463, 0.1410, 0.1399, 0.1440,
#         0.1485, 0.1403, 0.1398, 0.1435])
#
# === Condition : Baseline ===
# Train Baseline: 100%|█| 11/11 [20:41<00:00, 112.82s/epoch, Loss=0.7624, ValAcc=3
#
# --- Évaluation détaillée par sujet ---
#  >> Moyenne Globale Finale pour Baseline : 32.06%
#
# === Condition : FreqAug ===
# Train FreqAug: 100%|█| 11/11 [20:36<00:00, 112.43s/epoch, Loss=0.6519, ValAcc=40
#
# --- Évaluation détaillée par sujet ---
#  >> Moyenne Globale Finale pour FreqAug : 49.19%
#
# === Condition : GausAug ===
# ...
